# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import sys
import matplotlib.pyplot as plt
import seaborn as sns

sys.path.append("..")

# %% [markdown]
# ### Load Data

# %%
from src.data.load_data import load_tables

accidents, weather, raw = load_tables()

# %% [markdown]
# ### Datetime Verifications

# %%
accidents.dtypes
weather.dtypes
raw.dtypes

# %%
accidents["TW"] = pd.to_datetime(accidentes["TW"])
weather["TW"] = pd.to_datetime(clima["TW"])
raw["TW"] = pd.to_datetime(raw["TW"])
